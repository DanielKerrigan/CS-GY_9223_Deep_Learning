# %%
import os
import sys
sys.path.insert(0, os.path.abspath('./rlcard'))

# %%
import numpy as np

import rlcard
from rlcard.agents import RandomAgent, CFRAgent
from rlcard.utils import set_global_seed, tournament
from rlcard.utils import Logger
# Out:
# /Users/Dan/anaconda3/envs/dl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/Dan/anaconda3/envs/dl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/Dan/anaconda3/envs/dl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/Dan/anaconda3/envs/dl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/Dan/anaconda3/envs/dl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/Dan/anaconda3/envs/dl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /Users/Dan/anaconda3/envs/dl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/Dan/anaconda3/envs/dl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/Dan/anaconda3/envs/dl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/Dan/anaconda3/envs/dl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/Dan/anaconda3/envs/dl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/Dan/anaconda3/envs/dl/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# Make environment and enable human mode
env = rlcard.make('leduc-holdem', config={'seed': 0, 'allow_step_back':True})
eval_env = rlcard.make('leduc-holdem', config={'seed': 0})

# %%
# Set the iterations numbers and how frequently we evaluate/save plot
evaluate_every = 100
save_plot_every = 1000
evaluate_num = 10000
episode_num = 10000

# The paths for saving the logs and learning curves
log_dir = './experiments/leduc_holdem_cfr_result/'

# Set a global seed
set_global_seed(0)

# Initilize CFR Agent
agent = CFRAgent(env, model_path='./models/leduc_holdem_cfr')

random_agent = RandomAgent(action_num=env.action_num)

# Evaluate CFR against pre-trained NFSP
eval_env.set_agents([agent, random_agent])

# Init a Logger to plot the learning curve
logger = Logger(log_dir)
# Out:
# WARNING:tensorflow:From /Users/Dan/nyu/classes/deep-learning/project/src/rlcard/rlcard/utils/utils.py:332: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.

# %% [markdown]
# * Now we start to train CFR on Lecuc Hold'em. The training logs and the learning curves are shown as below.

# %%
for episode in range(episode_num):
    agent.train()
    print('\rIteration {}'.format(episode), end='')
    if episode % evaluate_every == 0:
        agent.save() # Save model
        logger.log_performance(episode, tournament(eval_env, evaluate_num)[0])
# Out:
# Iteration 0
# ----------------------------------------
#   timestep     |  0
#   reward       |  -0.0292
# ----------------------------------------
# Iteration 100
# ----------------------------------------
#   timestep     |  100
#   reward       |  0.4784
# ----------------------------------------
# Iteration 200
# ----------------------------------------
#   timestep     |  200
#   reward       |  0.63435
# ----------------------------------------
# Iteration 300
# ----------------------------------------
#   timestep     |  300
#   reward       |  0.6745
# ----------------------------------------
# Iteration 400
# ----------------------------------------
#   timestep     |  400
#   reward       |  0.8033
# ----------------------------------------
# Iteration 500
# ----------------------------------------
#   timestep     |  500
#   reward       |  0.79115
# ----------------------------------------
# Iteration 600
# ----------------------------------------
#   timestep     |  600
#   reward       |  0.82865
# ----------------------------------------
# Iteration 700
# ----------------------------------------
#   timestep     |  700
#   reward       |  0.8386
# ----------------------------------------
# Iteration 800
# ----------------------------------------
#   timestep     |  800
#   reward       |  0.8553
# ----------------------------------------
# Iteration 900
# ----------------------------------------
#   timestep     |  900
#   reward       |  0.83985
# ----------------------------------------
# Iteration 1000
# ----------------------------------------
#   timestep     |  1000
#   reward       |  0.7876
# ----------------------------------------
# Iteration 1100
# ----------------------------------------
#   timestep     |  1100
#   reward       |  0.87005
# ----------------------------------------
# Iteration 1200
# ----------------------------------------
#   timestep     |  1200
#   reward       |  0.82295
# ----------------------------------------
# Iteration 1300
# ----------------------------------------
#   timestep     |  1300
#   reward       |  0.83345
# ----------------------------------------
# Iteration 1400
# ----------------------------------------
#   timestep     |  1400
#   reward       |  0.8064
# ----------------------------------------
# Iteration 1500
# ----------------------------------------
#   timestep     |  1500
#   reward       |  0.8418
# ----------------------------------------
# Iteration 1600
# ----------------------------------------
#   timestep     |  1600
#   reward       |  0.79625
# ----------------------------------------
# Iteration 1700
# ----------------------------------------
#   timestep     |  1700
#   reward       |  0.813
# ----------------------------------------
# Iteration 1800
# ----------------------------------------
#   timestep     |  1800
#   reward       |  0.81185
# ----------------------------------------
# Iteration 1900
# ----------------------------------------
#   timestep     |  1900
#   reward       |  0.86485
# ----------------------------------------
# Iteration 2000
# ----------------------------------------
#   timestep     |  2000
#   reward       |  0.8418
# ----------------------------------------
# Iteration 2100
# ----------------------------------------
#   timestep     |  2100
#   reward       |  0.8222
# ----------------------------------------
# Iteration 2200
# ----------------------------------------
#   timestep     |  2200
#   reward       |  0.86075
# ----------------------------------------
# Iteration 2300
# ----------------------------------------
#   timestep     |  2300
#   reward       |  0.8159
# ----------------------------------------
# Iteration 2400
# ----------------------------------------
#   timestep     |  2400
#   reward       |  0.82665
# ----------------------------------------
# Iteration 2500
# ----------------------------------------
#   timestep     |  2500
#   reward       |  0.85805
# ----------------------------------------
# Iteration 2600
# ----------------------------------------
#   timestep     |  2600
#   reward       |  0.80755
# ----------------------------------------
# Iteration 2700
# ----------------------------------------
#   timestep     |  2700
#   reward       |  0.85215
# ----------------------------------------
# Iteration 2800
# ----------------------------------------
#   timestep     |  2800
#   reward       |  0.8276
# ----------------------------------------
# Iteration 2900
# ----------------------------------------
#   timestep     |  2900
#   reward       |  0.85115
# ----------------------------------------
# Iteration 3000
# ----------------------------------------
#   timestep     |  3000
#   reward       |  0.79505
# ----------------------------------------
# Iteration 3100
# ----------------------------------------
#   timestep     |  3100
#   reward       |  0.8292
# ----------------------------------------
# Iteration 3200
# ----------------------------------------
#   timestep     |  3200
#   reward       |  0.80585
# ----------------------------------------
# Iteration 3300
# ----------------------------------------
#   timestep     |  3300
#   reward       |  0.7585
# ----------------------------------------
# Iteration 3400
# ----------------------------------------
#   timestep     |  3400
#   reward       |  0.77845
# ----------------------------------------
# Iteration 3500
# ----------------------------------------
#   timestep     |  3500
#   reward       |  0.77195
# ----------------------------------------
# Iteration 3600
# ----------------------------------------
#   timestep     |  3600
#   reward       |  0.758
# ----------------------------------------
# Iteration 3700
# ----------------------------------------
#   timestep     |  3700
#   reward       |  0.8286
# ----------------------------------------
# Iteration 3800
# ----------------------------------------
#   timestep     |  3800
#   reward       |  0.78085
# ----------------------------------------
# Iteration 3900
# ----------------------------------------
#   timestep     |  3900
#   reward       |  0.77615
# ----------------------------------------
# Iteration 4000
# ----------------------------------------
#   timestep     |  4000
#   reward       |  0.84045
# ----------------------------------------
# Iteration 4100
# ----------------------------------------
#   timestep     |  4100
#   reward       |  0.81235
# ----------------------------------------
# Iteration 4200
# ----------------------------------------
#   timestep     |  4200
#   reward       |  0.7624
# ----------------------------------------
# Iteration 4300
# ----------------------------------------
#   timestep     |  4300
#   reward       |  0.7841
# ----------------------------------------
# Iteration 4400
# ----------------------------------------
#   timestep     |  4400
#   reward       |  0.7739
# ----------------------------------------
# Iteration 4500
# ----------------------------------------
#   timestep     |  4500
#   reward       |  0.7822
# ----------------------------------------
# Iteration 4600
# ----------------------------------------
#   timestep     |  4600
#   reward       |  0.78565
# ----------------------------------------
# Iteration 4700
# ----------------------------------------
#   timestep     |  4700
#   reward       |  0.77575
# ----------------------------------------
# Iteration 4800
# ----------------------------------------
#   timestep     |  4800
#   reward       |  0.7879
# ----------------------------------------
# Iteration 4900
# ----------------------------------------
#   timestep     |  4900
#   reward       |  0.805
# ----------------------------------------
# Iteration 5000
# ----------------------------------------
#   timestep     |  5000
#   reward       |  0.78545
# ----------------------------------------
# Iteration 5100
# ----------------------------------------
#   timestep     |  5100
#   reward       |  0.79495
# ----------------------------------------
# Iteration 5200
# ----------------------------------------
#   timestep     |  5200
#   reward       |  0.763
# ----------------------------------------
# Iteration 5300
# ----------------------------------------
#   timestep     |  5300
#   reward       |  0.7606
# ----------------------------------------
# Iteration 5400
# ----------------------------------------
#   timestep     |  5400
#   reward       |  0.7677
# ----------------------------------------
# Iteration 5500
# ----------------------------------------
#   timestep     |  5500
#   reward       |  0.8187
# ----------------------------------------
# Iteration 5600
# ----------------------------------------
#   timestep     |  5600
#   reward       |  0.8331
# ----------------------------------------
# Iteration 5700
# ----------------------------------------
#   timestep     |  5700
#   reward       |  0.793
# ----------------------------------------
# Iteration 5800
# ----------------------------------------
#   timestep     |  5800
#   reward       |  0.7922
# ----------------------------------------
# Iteration 5900
# ----------------------------------------
#   timestep     |  5900
#   reward       |  0.789
# ----------------------------------------
# Iteration 6000
# ----------------------------------------
#   timestep     |  6000
#   reward       |  0.78395
# ----------------------------------------
# Iteration 6100
# ----------------------------------------
#   timestep     |  6100
#   reward       |  0.7665
# ----------------------------------------
# Iteration 6200
# ----------------------------------------
#   timestep     |  6200
#   reward       |  0.73615
# ----------------------------------------
# Iteration 6300
# ----------------------------------------
#   timestep     |  6300
#   reward       |  0.76005
# ----------------------------------------
# Iteration 6400
# ----------------------------------------
#   timestep     |  6400
#   reward       |  0.7721
# ----------------------------------------
# Iteration 6500
# ----------------------------------------
#   timestep     |  6500
#   reward       |  0.7478
# ----------------------------------------
# Iteration 6600
# ----------------------------------------
#   timestep     |  6600
#   reward       |  0.74445
# ----------------------------------------
# Iteration 6700
# ----------------------------------------
#   timestep     |  6700
#   reward       |  0.7272
# ----------------------------------------
# Iteration 6800
# ----------------------------------------
#   timestep     |  6800
#   reward       |  0.74095
# ----------------------------------------
# Iteration 6900
# ----------------------------------------
#   timestep     |  6900
#   reward       |  0.77455
# ----------------------------------------
# Iteration 7000
# ----------------------------------------
#   timestep     |  7000
#   reward       |  0.79045
# ----------------------------------------
# Iteration 7100
# ----------------------------------------
#   timestep     |  7100
#   reward       |  0.74755
# ----------------------------------------
# Iteration 7200
# ----------------------------------------
#   timestep     |  7200
#   reward       |  0.7683
# ----------------------------------------
# Iteration 7300
# ----------------------------------------
#   timestep     |  7300
#   reward       |  0.76775
# ----------------------------------------
# Iteration 7400
# ----------------------------------------
#   timestep     |  7400
#   reward       |  0.72855
# ----------------------------------------
# Iteration 7500
# ----------------------------------------
#   timestep     |  7500
#   reward       |  0.78595
# ----------------------------------------
# Iteration 7600
# ----------------------------------------
#   timestep     |  7600
#   reward       |  0.75585
# ----------------------------------------
# Iteration 7700
# ----------------------------------------
#   timestep     |  7700
#   reward       |  0.7734
# ----------------------------------------
# Iteration 7800
# ----------------------------------------
#   timestep     |  7800
#   reward       |  0.8067
# ----------------------------------------
# Iteration 7900
# ----------------------------------------
#   timestep     |  7900
#   reward       |  0.75135
# ----------------------------------------
# Iteration 8000
# ----------------------------------------
#   timestep     |  8000
#   reward       |  0.7545
# ----------------------------------------
# Iteration 8100
# ----------------------------------------
#   timestep     |  8100
#   reward       |  0.74805
# ----------------------------------------
# Iteration 8200
# ----------------------------------------
#   timestep     |  8200
#   reward       |  0.73385
# ----------------------------------------
# Iteration 8300
# ----------------------------------------
#   timestep     |  8300
#   reward       |  0.7577
# ----------------------------------------
# Iteration 8400
# ----------------------------------------
#   timestep     |  8400
#   reward       |  0.78905
# ----------------------------------------
# Iteration 8500
# ----------------------------------------
#   timestep     |  8500
#   reward       |  0.8027
# ----------------------------------------
# Iteration 8600
# ----------------------------------------
#   timestep     |  8600
#   reward       |  0.7302
# ----------------------------------------
# Iteration 8700
# ----------------------------------------
#   timestep     |  8700
#   reward       |  0.7547
# ----------------------------------------
# Iteration 8800
# ----------------------------------------
#   timestep     |  8800
#   reward       |  0.74335
# ----------------------------------------
# Iteration 8900
# ----------------------------------------
#   timestep     |  8900
#   reward       |  0.78625
# ----------------------------------------
# Iteration 9000
# ----------------------------------------
#   timestep     |  9000
#   reward       |  0.81075
# ----------------------------------------
# Iteration 9100
# ----------------------------------------
#   timestep     |  9100
#   reward       |  0.7473
# ----------------------------------------
# Iteration 9200
# ----------------------------------------
#   timestep     |  9200
#   reward       |  0.8017
# ----------------------------------------
# Iteration 9300
# ----------------------------------------
#   timestep     |  9300
#   reward       |  0.76355
# ----------------------------------------
# Iteration 9400
# ----------------------------------------
#   timestep     |  9400
#   reward       |  0.77905
# ----------------------------------------
# Iteration 9500
# ----------------------------------------
#   timestep     |  9500
#   reward       |  0.7589
# ----------------------------------------
# Iteration 9600
# ----------------------------------------
#   timestep     |  9600
#   reward       |  0.76525
# ----------------------------------------
# Iteration 9700
# ----------------------------------------
#   timestep     |  9700
#   reward       |  0.77765
# ----------------------------------------
# Iteration 9800
# ----------------------------------------
#   timestep     |  9800
#   reward       |  0.7533
# ----------------------------------------
# Iteration 9900
# ----------------------------------------
#   timestep     |  9900
#   reward       |  0.76685
# ----------------------------------------
# Iteration 9999

# %%
# Close files in the logger
logger.close_files()

# Plot the learning curve
logger.plot('CFR')
# Out:
# ./experiments/leduc_holdem_cfr_result/performance.csv
