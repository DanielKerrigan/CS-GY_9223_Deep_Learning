# %% [markdown]
# Reference: https://github.com/datamllab/rlcard-tutorial/blob/master/python/leduc_holdem_cfr.ipynb

# %%
import os
import sys
sys.path.insert(0, os.path.abspath('./rlcard'))

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import numpy as np

import rlcard
from rlcard.agents import RandomAgent, CFRAgent
from rlcard.utils import set_global_seed, tournament
from rlcard.utils import Logger

# %%
# Make environment and enable human mode
env = rlcard.make('leduc-holdem', config={'seed': 0, 'allow_step_back':True})
eval_env = rlcard.make('leduc-holdem', config={'seed': 0})

# %%
# Set the iterations numbers and how frequently we evaluate/save plot
evaluate_every = 10_000
save_plot_every = 10_000
evaluate_num = 10_000
episode_num = 1_000_000

# The paths for saving the logs and learning curves
log_dir = './experiments/leduc_holdem_cfr_result_million/'

# Set a global seed
set_global_seed(0)

# Initilize CFR Agent
agent = CFRAgent(env, model_path='./models/leduc_holdem_cfr_million')

random_agent = RandomAgent(action_num=env.action_num)

# Evaluate CFR against random agent
eval_env.set_agents([agent, random_agent])

# Init a Logger to plot the learning curve
logger = Logger(log_dir)

# %%
for episode in range(episode_num):
    agent.train()
    print('\rIteration {}'.format(episode), end='')
    if episode % evaluate_every == 0:
        agent.save() # Save model
        logger.log_performance(episode, tournament(eval_env, evaluate_num)[0])
# Out:
# Iteration 0
# ----------------------------------------
#   timestep     |  0
#   reward       |  -0.0085
# ----------------------------------------
# Iteration 10000
# ----------------------------------------
#   timestep     |  10000
#   reward       |  0.6576
# ----------------------------------------
# Iteration 20000
# ----------------------------------------
#   timestep     |  20000
#   reward       |  0.73545
# ----------------------------------------
# Iteration 30000
# ----------------------------------------
#   timestep     |  30000
#   reward       |  0.6912
# ----------------------------------------
# Iteration 40000
# ----------------------------------------
#   timestep     |  40000
#   reward       |  0.694
# ----------------------------------------
# Iteration 50000
# ----------------------------------------
#   timestep     |  50000
#   reward       |  0.68585
# ----------------------------------------
# Iteration 60000
# ----------------------------------------
#   timestep     |  60000
#   reward       |  0.6858
# ----------------------------------------
# Iteration 70000
# ----------------------------------------
#   timestep     |  70000
#   reward       |  0.71135
# ----------------------------------------
# Iteration 80000
# ----------------------------------------
#   timestep     |  80000
#   reward       |  0.6892
# ----------------------------------------
# Iteration 90000
# ----------------------------------------
#   timestep     |  90000
#   reward       |  0.7163
# ----------------------------------------
# Iteration 100000
# ----------------------------------------
#   timestep     |  100000
#   reward       |  0.73005
# ----------------------------------------
# Iteration 110000
# ----------------------------------------
#   timestep     |  110000
#   reward       |  0.7059
# ----------------------------------------
# Iteration 120000
# ----------------------------------------
#   timestep     |  120000
#   reward       |  0.7228
# ----------------------------------------
# Iteration 130000
# ----------------------------------------
#   timestep     |  130000
#   reward       |  0.71145
# ----------------------------------------
# Iteration 140000
# ----------------------------------------
#   timestep     |  140000
#   reward       |  0.6736
# ----------------------------------------
# Iteration 150000
# ----------------------------------------
#   timestep     |  150000
#   reward       |  0.6984
# ----------------------------------------
# Iteration 160000
# ----------------------------------------
#   timestep     |  160000
#   reward       |  0.70015
# ----------------------------------------
# Iteration 170000
# ----------------------------------------
#   timestep     |  170000
#   reward       |  0.635
# ----------------------------------------
# Iteration 180000
# ----------------------------------------
#   timestep     |  180000
#   reward       |  0.6874
# ----------------------------------------
# Iteration 190000
# ----------------------------------------
#   timestep     |  190000
#   reward       |  0.7193
# ----------------------------------------
# Iteration 200000
# ----------------------------------------
#   timestep     |  200000
#   reward       |  0.69015
# ----------------------------------------
# Iteration 210000
# ----------------------------------------
#   timestep     |  210000
#   reward       |  0.7212
# ----------------------------------------
# Iteration 220000
# ----------------------------------------
#   timestep     |  220000
#   reward       |  0.6944
# ----------------------------------------
# Iteration 230000
# ----------------------------------------
#   timestep     |  230000
#   reward       |  0.6889
# ----------------------------------------
# Iteration 240000
# ----------------------------------------
#   timestep     |  240000
#   reward       |  0.6948
# ----------------------------------------
# Iteration 250000
# ----------------------------------------
#   timestep     |  250000
#   reward       |  0.7477
# ----------------------------------------
# Iteration 260000
# ----------------------------------------
#   timestep     |  260000
#   reward       |  0.69315
# ----------------------------------------
# Iteration 270000
# ----------------------------------------
#   timestep     |  270000
#   reward       |  0.69205
# ----------------------------------------
# Iteration 280000
# ----------------------------------------
#   timestep     |  280000
#   reward       |  0.68185
# ----------------------------------------
# Iteration 290000
# ----------------------------------------
#   timestep     |  290000
#   reward       |  0.72955
# ----------------------------------------
# Iteration 300000
# ----------------------------------------
#   timestep     |  300000
#   reward       |  0.6966
# ----------------------------------------
# Iteration 310000
# ----------------------------------------
#   timestep     |  310000
#   reward       |  0.7238
# ----------------------------------------
# Iteration 320000
# ----------------------------------------
#   timestep     |  320000
#   reward       |  0.6808
# ----------------------------------------
# Iteration 330000
# ----------------------------------------
#   timestep     |  330000
#   reward       |  0.65815
# ----------------------------------------
# Iteration 340000
# ----------------------------------------
#   timestep     |  340000
#   reward       |  0.6921
# ----------------------------------------
# Iteration 350000
# ----------------------------------------
#   timestep     |  350000
#   reward       |  0.695
# ----------------------------------------
# Iteration 360000
# ----------------------------------------
#   timestep     |  360000
#   reward       |  0.62845
# ----------------------------------------
# Iteration 370000
# ----------------------------------------
#   timestep     |  370000
#   reward       |  0.709
# ----------------------------------------
# Iteration 380000
# ----------------------------------------
#   timestep     |  380000
#   reward       |  0.67
# ----------------------------------------
# Iteration 390000
# ----------------------------------------
#   timestep     |  390000
#   reward       |  0.7238
# ----------------------------------------
# Iteration 400000
# ----------------------------------------
#   timestep     |  400000
#   reward       |  0.7406
# ----------------------------------------
# Iteration 410000
# ----------------------------------------
#   timestep     |  410000
#   reward       |  0.6564
# ----------------------------------------
# Iteration 420000
# ----------------------------------------
#   timestep     |  420000
#   reward       |  0.6729
# ----------------------------------------
# Iteration 430000
# ----------------------------------------
#   timestep     |  430000
#   reward       |  0.69605
# ----------------------------------------
# Iteration 440000
# ----------------------------------------
#   timestep     |  440000
#   reward       |  0.6856
# ----------------------------------------
# Iteration 450000
# ----------------------------------------
#   timestep     |  450000
#   reward       |  0.66865
# ----------------------------------------
# Iteration 460000
# ----------------------------------------
#   timestep     |  460000
#   reward       |  0.70315
# ----------------------------------------
# Iteration 470000
# ----------------------------------------
#   timestep     |  470000
#   reward       |  0.65535
# ----------------------------------------
# Iteration 480000
# ----------------------------------------
#   timestep     |  480000
#   reward       |  0.67925
# ----------------------------------------
# Iteration 490000
# ----------------------------------------
#   timestep     |  490000
#   reward       |  0.68135
# ----------------------------------------
# Iteration 500000
# ----------------------------------------
#   timestep     |  500000
#   reward       |  0.7106
# ----------------------------------------
# Iteration 510000
# ----------------------------------------
#   timestep     |  510000
#   reward       |  0.74255
# ----------------------------------------
# Iteration 520000
# ----------------------------------------
#   timestep     |  520000
#   reward       |  0.678
# ----------------------------------------
# Iteration 530000
# ----------------------------------------
#   timestep     |  530000
#   reward       |  0.68925
# ----------------------------------------
# Iteration 540000
# ----------------------------------------
#   timestep     |  540000
#   reward       |  0.7065
# ----------------------------------------
# Iteration 550000
# ----------------------------------------
#   timestep     |  550000
#   reward       |  0.70475
# ----------------------------------------
# Iteration 560000
# ----------------------------------------
#   timestep     |  560000
#   reward       |  0.7174
# ----------------------------------------
# Iteration 570000
# ----------------------------------------
#   timestep     |  570000
#   reward       |  0.7087
# ----------------------------------------
# Iteration 580000
# ----------------------------------------
#   timestep     |  580000
#   reward       |  0.7171
# ----------------------------------------
# Iteration 590000
# ----------------------------------------
#   timestep     |  590000
#   reward       |  0.6757
# ----------------------------------------
# Iteration 600000
# ----------------------------------------
#   timestep     |  600000
#   reward       |  0.6967
# ----------------------------------------
# Iteration 610000
# ----------------------------------------
#   timestep     |  610000
#   reward       |  0.7102
# ----------------------------------------
# Iteration 620000
# ----------------------------------------
#   timestep     |  620000
#   reward       |  0.70155
# ----------------------------------------
# Iteration 630000
# ----------------------------------------
#   timestep     |  630000
#   reward       |  0.69425
# ----------------------------------------
# Iteration 640000
# ----------------------------------------
#   timestep     |  640000
#   reward       |  0.668
# ----------------------------------------
# Iteration 650000
# ----------------------------------------
#   timestep     |  650000
#   reward       |  0.6603
# ----------------------------------------
# Iteration 660000
# ----------------------------------------
#   timestep     |  660000
#   reward       |  0.7034
# ----------------------------------------
# Iteration 670000
# ----------------------------------------
#   timestep     |  670000
#   reward       |  0.68145
# ----------------------------------------
# Iteration 680000
# ----------------------------------------
#   timestep     |  680000
#   reward       |  0.66815
# ----------------------------------------
# Iteration 690000
# ----------------------------------------
#   timestep     |  690000
#   reward       |  0.69135
# ----------------------------------------
# Iteration 700000
# ----------------------------------------
#   timestep     |  700000
#   reward       |  0.7172
# ----------------------------------------
# Iteration 710000
# ----------------------------------------
#   timestep     |  710000
#   reward       |  0.64325
# ----------------------------------------
# Iteration 720000
# ----------------------------------------
#   timestep     |  720000
#   reward       |  0.6637
# ----------------------------------------
# Iteration 730000
# ----------------------------------------
#   timestep     |  730000
#   reward       |  0.6772
# ----------------------------------------
# Iteration 740000
# ----------------------------------------
#   timestep     |  740000
#   reward       |  0.64175
# ----------------------------------------
# Iteration 750000
# ----------------------------------------
#   timestep     |  750000
#   reward       |  0.6843
# ----------------------------------------
# Iteration 760000
# ----------------------------------------
#   timestep     |  760000
#   reward       |  0.6657
# ----------------------------------------
# Iteration 770000
# ----------------------------------------
#   timestep     |  770000
#   reward       |  0.6877
# ----------------------------------------
# Iteration 780000
# ----------------------------------------
#   timestep     |  780000
#   reward       |  0.6415
# ----------------------------------------
# Iteration 790000
# ----------------------------------------
#   timestep     |  790000
#   reward       |  0.6734
# ----------------------------------------
# Iteration 800000
# ----------------------------------------
#   timestep     |  800000
#   reward       |  0.6338
# ----------------------------------------
# Iteration 810000
# ----------------------------------------
#   timestep     |  810000
#   reward       |  0.6361
# ----------------------------------------
# Iteration 820000
# ----------------------------------------
#   timestep     |  820000
#   reward       |  0.69285
# ----------------------------------------
# Iteration 830000
# ----------------------------------------
#   timestep     |  830000
#   reward       |  0.7038
# ----------------------------------------
# Iteration 840000
# ----------------------------------------
#   timestep     |  840000
#   reward       |  0.66395
# ----------------------------------------
# Iteration 850000
# ----------------------------------------
#   timestep     |  850000
#   reward       |  0.7273
# ----------------------------------------
# Iteration 860000
# ----------------------------------------
#   timestep     |  860000
#   reward       |  0.662
# ----------------------------------------
# Iteration 870000
# ----------------------------------------
#   timestep     |  870000
#   reward       |  0.67295
# ----------------------------------------
# Iteration 880000
# ----------------------------------------
#   timestep     |  880000
#   reward       |  0.6458
# ----------------------------------------
# Iteration 890000
# ----------------------------------------
#   timestep     |  890000
#   reward       |  0.67515
# ----------------------------------------
# Iteration 900000
# ----------------------------------------
#   timestep     |  900000
#   reward       |  0.68705
# ----------------------------------------
# Iteration 910000
# ----------------------------------------
#   timestep     |  910000
#   reward       |  0.6495
# ----------------------------------------
# Iteration 920000
# ----------------------------------------
#   timestep     |  920000
#   reward       |  0.67615
# ----------------------------------------
# Iteration 930000
# ----------------------------------------
#   timestep     |  930000
#   reward       |  0.6707
# ----------------------------------------
# Iteration 940000
# ----------------------------------------
#   timestep     |  940000
#   reward       |  0.6814
# ----------------------------------------
# Iteration 950000
# ----------------------------------------
#   timestep     |  950000
#   reward       |  0.6854
# ----------------------------------------
# Iteration 960000
# ----------------------------------------
#   timestep     |  960000
#   reward       |  0.67295
# ----------------------------------------
# Iteration 970000
# ----------------------------------------
#   timestep     |  970000
#   reward       |  0.6703
# ----------------------------------------
# Iteration 980000
# ----------------------------------------
#   timestep     |  980000
#   reward       |  0.67975
# ----------------------------------------
# Iteration 990000
# ----------------------------------------
#   timestep     |  990000
#   reward       |  0.65745
# ----------------------------------------
# Iteration 999999

# %%
# Close files in the logger
logger.close_files()

# Plot the learning curve
logger.plot('CFR')
# Out:
# ./experiments/leduc_holdem_cfr_result_million/performance.csv

# %%
eval_env_cfr_cfr = rlcard.make('leduc-holdem', config={'seed': 1})
eval_env_cfr_cfr.set_agents([agent, agent])
payoffs = tournament(eval_env_cfr_cfr, 10000)
print(payoffs)
# Out:
# [-0.0055, 0.0055]
